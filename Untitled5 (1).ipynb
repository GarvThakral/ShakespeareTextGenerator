# %%
# !pip install 'tensorflow[and-cuda]' 
# !pip install datasets nltk

# %%
import tensorflow as tf
from datasets import load_dataset
from tensorflow.keras.layers import LSTM , Input , Embedding , Dropout , Dense
from tensorflow.keras import Model
import re
import logging
import numpy as np

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip
# nltk.download('stopwords')
# stopwords = nltk.corpus.stopwords.words('english')

# %%
ds = load_dataset("Trelis/tiny-shakespeare")
maxInDs = 0
for x in ds['train']:
  sentence_array = re.findall(r"\b\w+(?:'\w+)?\b|[.!?,-]", x['Text'].lower())
  maxInDs = max(len(sentence_array),maxInDs)
maxInDs
# Out:
# 739

# %%
# Making my own dicrtionary from the dataset
newVocab = []

def create_new_vocab(sentence,newVocab):
  sentence_array = re.findall(r"\b\w+(?:'\w+)?\b|[.!?,-]", sentence.lower())
  new_words = [x for x in sentence_array if x not in newVocab]
  new_words_set = set(new_words)
  new_words = list(new_words_set)
  newVocab += new_words

ds['train'].map(lambda x : create_new_vocab(x["Text"],newVocab))
ds['test'].map(lambda x : create_new_vocab(x["Text"],newVocab))
newVocab.insert(0,"<UNK>")
newVocab.insert(0,"<PAD>")
# Out:
# Map:   0%|          | 0/472 [00:00<?, ? examples/s]
# Map:   0%|          | 0/49 [00:00<?, ? examples/s]

# %%
vocab_size = len(newVocab)
index_to_word = {i:k for i,k in enumerate(newVocab)}
word_to_index = {k:i for i,k in enumerate(newVocab)}

# %%
def preprocessing_layer(sentence):
  sentence_array = re.findall(r"\b\w+(?:'\w+)?\b|[.!?,-]", sentence.lower())
  # print(sentence_array)
  wor_to_in = [word_to_index[x] for x in sentence_array]
  # print(wor_to_in)
  pad_len = maxInDs - len(wor_to_in)
  zero_array = [0]*pad_len
  # print(len(wor_to_in))
  padded_wor_to_in = wor_to_in+zero_array
  # print(len(padded_wor_to_in))
  if(len(padded_wor_to_in) > maxInDs):
    logging.log("BRUHHHHH")
    return "STOP"
  labels = padded_wor_to_in[1:] + [0]
  return {"features":padded_wor_to_in,"labels":labels}

processed_ds_train = ds['train'].map(lambda x : preprocessing_layer(x["Text"]))
processed_ds_test = ds['test'].map(lambda x : preprocessing_layer(x["Text"]))
# Out:
# Map:   0%|          | 0/472 [00:00<?, ? examples/s]
# Map:   0%|          | 0/49 [00:00<?, ? examples/s]

# %%
tf_ds_train = processed_ds_train.to_tf_dataset(
    columns = ['features'],
    label_cols=['labels'],
    batch_size = 10,
    shuffle = True
)
tf_ds_test = processed_ds_test.to_tf_dataset(
    columns = ['features'],
    label_cols=['labels'],
    batch_size = 10,
    shuffle = True
)
# Out:
# /home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/datasets/arrow_dataset.py:403: FutureWarning: The output of `to_tf_dataset` will change when a passing single element list for `labels` or `columns` in the next datasets version. To return a tuple structure rather than dict, pass a single string.
# Old behaviour: columns=['a'], labels=['labels'] -> (tf.Tensor, tf.Tensor)
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
# New behaviour: columns=['a'],labels=['labels'] -> ({'a': tf.Tensor}, {'labels': tf.Tensor})
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757099906.433476   48600 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1171 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
def embedding_layer_generator():
  embedding_layer = Embedding(
      input_dim = vocab_size,
      output_dim = 300,
      mask_zero = True
  )
  return embedding_layer
emb_layer = embedding_layer_generator()

# %%
# import numpy as np

# embeddings_index = {}
# with open("glove.6B.200d.txt", encoding="utf8") as f:  # pick 50d/100d/200d/300d
#     for line in f:
#         values = line.split()
#         word = values[0]
#         vector = np.asarray(values[1:], dtype="float32")
#         embeddings_index[word] = vector

# print("Loaded %s word vectors." % len(embeddings_index))

# %%
# for x,y in embeddings_index.items():
#   print(x)
#   break

# %%
# lastIndexEmb = len(list(embeddings_index.keys()))
# lastIndexEmb

# %%
# embDim = len(embeddings_index['random'])
# embDim

# %%
# # Reserve 0 for <PAD>
# word_to_index = {"<PAD>": 0, "<UNK>": 1}

# for i, word in enumerate(embeddings_index.keys(), start=2):
#     word_to_index[word] = i

# word_to_index['the']

# %%
# vocab_size = len(word_to_index)
# embedding_matrix = np.zeros((vocab_size, embDim))

# for word, idx in word_to_index.items():
#     if word == "<PAD>":
#         embedding_matrix[idx] = np.zeros(embDim)
#     elif word == "<UNK>":
#         embedding_matrix[idx] = np.random.uniform(-0.05, 0.05, embDim)
#     else:
#         embedding_matrix[idx] = embeddings_index.get(word, np.random.uniform(-0.05, 0.05, embDim))

# %%
# This is the embedding layer with glove

# def embedding_layer():
#   emb_layer = Embedding(
#       input_dim=vocab_size,
#       output_dim=embDim,
#       weights=[embedding_matrix],
#       trainable=False,
#       mask_zero=True
#   )

#   return emb_layer
# emb_layer = embedding_layer()

# %%
# Preprocessing layer for glove

# def preprocessing_layer(sentence):
#     split = re.findall(r"\b\w+\b", sentence.lower())
#     sen_to_in = [word_to_index.get(x, word_to_index["<UNK>"]) for x in split]

#     # --- Features ---
#     features = sen_to_in + [0] * (maxInDs - len(sen_to_in))
#     features = features[:maxInDs]

#     # --- Labels (shifted raw sequence, not padded features) ---
#     shifted = sen_to_in[1:] + [0]   # one step ahead
#     labels = shifted + [0] * (maxInDs - len(shifted))
#     labels = labels[:maxInDs]

#     return {"features": features, "labels": labels}

# %%
# ds['train'] = ds['train'].map(lambda x : preprocessing_layer(x['Text']))

# %%
# for x in ds['train']:
#   print(x)
#   break

# %%
# tf_ds = ds["train"].to_tf_dataset(
#     columns=["features"],
#     label_cols=["labels"],
#     shuffle=True,
#     batch_size=1
# )

# %%
# bad_rows = []
# for i, x in enumerate(ds["train"]):
#     if len(x["features"]) != maxInDs or len(x["labels"]) != maxInDs:
#         bad_rows.append((i, len(x["features"]), len(x["labels"])))

# if bad_rows:
#     print("❌ Found mismatched rows:")
#     for row in bad_rows[:10]:  # sirf first 10 print karo
#         print(f"Index={row[0]}, features={row[1]}, labels={row[2]}, expected={maxInDs}")
# else:
#     print("✅ All rows match expected length =", maxInDs)

# %%
def shakesphereModel():
  inputs = tf.keras.layers.Input(shape = (maxInDs,))
  X = emb_layer(inputs)
  # LSTM Block 1
  X , _ , _ = LSTM(units = 256,activation = 'tanh' , return_sequences=True , return_state = True)(X)
  X = Dropout(0.4)(X)
  X , _ , _ = LSTM(units = 512,activation = 'tanh' , return_sequences=True ,return_state = True)(X)
  X = Dropout(0.4)(X)
  # X = LSTM(units = 256,activation = 'tanh' , return_sequences=True)(X)
  # X = Dropout(0.4)(X)
  X = Dense(units = vocab_size , activation = 'softmax')(X)
  outputs = X
  model = Model(inputs = inputs , outputs = outputs)
  return model
model = shakesphereModel()

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),optimizer = "adam" , metrics = [tf.keras.metrics.SparseCategoricalCrossentropy()])
model.fit(tf_ds_train,epochs=40)
# Out:
# Epoch 1/40
# 2025-09-06 00:49:41.569339: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 348.77MiB (rounded to 365716480)requested by op StatefulPartitionedCall/compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-09-06 00:49:41.569386: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# 2025-09-06 00:49:41.569403: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 76, Chunks in use: 76. 19.0KiB allocated for chunks. 19.0KiB in use in bin. 465B client-requested in use in bin.
# 2025-09-06 00:49:41.569412: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 1, Chunks in use: 0. 512B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569422: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 3, Chunks in use: 1. 3.5KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569429: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569438: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 7, Chunks in use: 6. 30.2KiB allocated for chunks. 26.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569447: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 11, Chunks in use: 11. 100.0KiB allocated for chunks. 100.0KiB in use in bin. 98.0KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569456: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 8, Chunks in use: 8. 194.8KiB allocated for chunks. 194.8KiB in use in bin. 186.6KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569464: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 6, Chunks in use: 6. 311.5KiB allocated for chunks. 311.5KiB in use in bin. 289.3KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569473: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 93.8KiB allocated for chunks. 93.8KiB in use in bin. 48.3KiB client-requested in use in bin.
# 2025-09-06 00:49:41.569479: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569486: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569493: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569501: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 7, Chunks in use: 7. 7.74MiB allocated for chunks. 7.74MiB in use in bin. 7.52MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569509: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 7, Chunks in use: 7. 15.96MiB allocated for chunks. 15.96MiB in use in bin. 13.16MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569518: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 8, Chunks in use: 8. 44.94MiB allocated for chunks. 44.94MiB in use in bin. 40.06MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569526: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 6, Chunks in use: 6. 80.44MiB allocated for chunks. 80.44MiB in use in bin. 79.80MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569535: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 6, Chunks in use: 6. 153.64MiB allocated for chunks. 153.64MiB in use in bin. 142.64MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569543: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 2, Chunks in use: 1. 100.49MiB allocated for chunks. 63.65MiB in use in bin. 63.65MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569555: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 82.98MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569562: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-09-06 00:49:41.569571: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 684.08MiB allocated for chunks. 348.77MiB in use in bin. 348.77MiB client-requested in use in bin.
# 2025-09-06 00:49:41.569579: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1072] Bin for 348.77MiB was 256.00MiB, Chunk State:
# 2025-09-06 00:49:41.569592: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1078]   Size: 335.30MiB | Requested Size: 256.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 348.77MiB | Requested Size: 348.77MiB | in_use: 1 | bin_num: -1
# 2025-09-06 00:49:41.569598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1085] Next region of size 1227882496
# 2025-09-06 00:49:41.569607: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000000 of size 256 next 1
# 2025-09-06 00:49:41.569613: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000100 of size 1280 next 2
# 2025-09-06 00:49:41.569619: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000600 of size 256 next 3
# 2025-09-06 00:49:41.569624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000700 of size 256 next 4
# 2025-09-06 00:49:41.569630: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000800 of size 256 next 5
# 2025-09-06 00:49:41.569635: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000900 of size 256 next 6
# 2025-09-06 00:49:41.569641: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000a00 of size 256 next 7
# 2025-09-06 00:49:41.569646: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000b00 of size 256 next 8
# 2025-09-06 00:49:41.569651: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000c00 of size 256 next 9
# 2025-09-06 00:49:41.569657: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000d00 of size 256 next 10
# 2025-09-06 00:49:41.569662: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000e00 of size 256 next 11
# 2025-09-06 00:49:41.569668: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502000f00 of size 256 next 12
# 2025-09-06 00:49:41.569673: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001000 of size 256 next 13
# 2025-09-06 00:49:41.569679: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001100 of size 256 next 14
# 2025-09-06 00:49:41.569684: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001200 of size 256 next 15
# 2025-09-06 00:49:41.569689: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001300 of size 256 next 17
# 2025-09-06 00:49:41.569694: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001400 of size 256 next 18
# 2025-09-06 00:49:41.569700: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001500 of size 256 next 16
# 2025-09-06 00:49:41.569705: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001600 of size 256 next 22
# 2025-09-06 00:49:41.569711: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001700 of size 256 next 23
# 2025-09-06 00:49:41.569716: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001800 of size 256 next 39
# 2025-09-06 00:49:41.569723: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001900 of size 256 next 33
# 2025-09-06 00:49:41.569728: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001a00 of size 256 next 40
# 2025-09-06 00:49:41.569734: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001b00 of size 256 next 99
# 2025-09-06 00:49:41.569739: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001c00 of size 256 next 42
# 2025-09-06 00:49:41.569744: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001d00 of size 256 next 43
# 2025-09-06 00:49:41.569750: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001e00 of size 256 next 47
# 2025-09-06 00:49:41.569755: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502001f00 of size 256 next 48
# 2025-09-06 00:49:41.569760: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502002000 of size 256 next 54
# 2025-09-06 00:49:41.569766: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502002100 of size 256 next 55
# 2025-09-06 00:49:41.569771: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502002200 of size 256 next 56
# 2025-09-06 00:49:41.569777: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502002300 of size 256 next 29
# 2025-09-06 00:49:41.569782: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502002400 of size 4096 next 30
# 2025-09-06 00:49:41.569788: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502003400 of size 6144 next 34
# 2025-09-06 00:49:41.569794: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502004c00 of size 8192 next 36
# 2025-09-06 00:49:41.569800: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502006c00 of size 49664 next 41
# 2025-09-06 00:49:41.569806: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502012e00 of size 8192 next 49
# 2025-09-06 00:49:41.569811: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502014e00 of size 49664 next 51
# 2025-09-06 00:49:41.569817: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502021000 of size 1181440 next 24
# 2025-09-06 00:49:41.569823: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141700 of size 256 next 27
# 2025-09-06 00:49:41.569828: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141800 of size 256 next 28
# 2025-09-06 00:49:41.569834: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141900 of size 256 next 31
# 2025-09-06 00:49:41.569839: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141a00 of size 256 next 32
# 2025-09-06 00:49:41.569845: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141b00 of size 256 next 19
# 2025-09-06 00:49:41.569850: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502141c00 of size 1146112 next 25
# 2025-09-06 00:49:41.569856: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502259900 of size 1228800 next 26
# 2025-09-06 00:49:41.569862: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502385900 of size 4194304 next 38
# 2025-09-06 00:49:41.569868: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502785900 of size 2097152 next 37
# 2025-09-06 00:49:41.569873: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502985900 of size 4194304 next 35
# 2025-09-06 00:49:41.569879: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743502d85900 of size 15520000 next 20
# 2025-09-06 00:49:41.569885: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743503c52a00 of size 14846464 next 21
# 2025-09-06 00:49:41.569892: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743504a7b400 of size 25337856 next 50
# 2025-09-06 00:49:41.569898: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435062a5400 of size 1228800 next 52
# 2025-09-06 00:49:41.569903: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435063d1400 of size 2097152 next 53
# 2025-09-06 00:49:41.569909: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1400 of size 256 next 57
# 2025-09-06 00:49:41.569932: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1500 of size 256 next 58
# 2025-09-06 00:49:41.569938: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1600 of size 256 next 59
# 2025-09-06 00:49:41.569944: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1700 of size 256 next 60
# 2025-09-06 00:49:41.569949: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1800 of size 256 next 61
# 2025-09-06 00:49:41.569955: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1900 of size 256 next 62
# 2025-09-06 00:49:41.569960: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1a00 of size 256 next 63
# 2025-09-06 00:49:41.569966: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d1b00 of size 8192 next 64
# 2025-09-06 00:49:41.569971: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d3b00 of size 256 next 65
# 2025-09-06 00:49:41.569977: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d3c00 of size 4096 next 66
# 2025-09-06 00:49:41.569983: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065d4c00 of size 96000 next 70
# 2025-09-06 00:49:41.569988: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065ec300 of size 8192 next 122
# 2025-09-06 00:49:41.569994: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065ee300 of size 4096 next 112
# 2025-09-06 00:49:41.569999: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065ef300 of size 8192 next 109
# 2025-09-06 00:49:41.570005: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f1300 of size 4096 next 143
# 2025-09-06 00:49:41.570011: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2300 of size 256 next 165
# 2025-09-06 00:49:41.570016: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2400 of size 256 next 166
# 2025-09-06 00:49:41.570022: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2500 of size 256 next 167
# 2025-09-06 00:49:41.570027: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2600 of size 256 next 168
# 2025-09-06 00:49:41.570033: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2700 of size 256 next 169
# 2025-09-06 00:49:41.570038: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2800 of size 256 next 171
# 2025-09-06 00:49:41.570043: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f2900 of size 12288 next 123
# 2025-09-06 00:49:41.570049: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f5900 of size 256 next 124
# 2025-09-06 00:49:41.570055: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f5a00 of size 8192 next 91
# 2025-09-06 00:49:41.570060: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f7a00 of size 4096 next 141
# 2025-09-06 00:49:41.570065: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8a00 of size 256 next 152
# 2025-09-06 00:49:41.570071: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8b00 of size 256 next 73
# 2025-09-06 00:49:41.570076: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8c00 of size 256 next 148
# 2025-09-06 00:49:41.570082: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8d00 of size 256 next 102
# 2025-09-06 00:49:41.570087: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8e00 of size 256 next 68
# 2025-09-06 00:49:41.570092: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f8f00 of size 256 next 147
# 2025-09-06 00:49:41.570098: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9000 of size 256 next 149
# 2025-09-06 00:49:41.570103: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9100 of size 256 next 107
# 2025-09-06 00:49:41.570109: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9200 of size 256 next 115
# 2025-09-06 00:49:41.570114: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9300 of size 256 next 151
# 2025-09-06 00:49:41.570119: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9400 of size 256 next 106
# 2025-09-06 00:49:41.570125: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9500 of size 256 next 118
# 2025-09-06 00:49:41.570131: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7435065f9600 of size 1024 next 92
# 2025-09-06 00:49:41.570136: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9a00 of size 256 next 93
# 2025-09-06 00:49:41.570142: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9b00 of size 256 next 94
# 2025-09-06 00:49:41.570147: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9c00 of size 256 next 121
# 2025-09-06 00:49:41.570152: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9d00 of size 256 next 128
# 2025-09-06 00:49:41.570158: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065f9e00 of size 256 next 90
# 2025-09-06 00:49:41.570163: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7435065f9f00 of size 512 next 105
# 2025-09-06 00:49:41.570169: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065fa100 of size 256 next 76
# 2025-09-06 00:49:41.570175: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435065fa200 of size 21844480 next 46
# 2025-09-06 00:49:41.570180: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743507acf400 of size 25337856 next 45
# 2025-09-06 00:49:41.570186: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435092f9400 of size 2277376 next 78
# 2025-09-06 00:49:41.570192: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743509525400 of size 2277376 next 113
# 2025-09-06 00:49:41.570198: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743509751400 of size 6598912 next 134
# 2025-09-06 00:49:41.570204: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743509d9c500 of size 29875712 next 133
# 2025-09-06 00:49:41.570209: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350ba1a300 of size 49664 next 74
# 2025-09-06 00:49:41.570215: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350ba26500 of size 1048576 next 137
# 2025-09-06 00:49:41.570220: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bb26500 of size 2097152 next 108
# 2025-09-06 00:49:41.570226: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd26500 of size 59136 next 140
# 2025-09-06 00:49:41.570232: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd34c00 of size 29696 next 150
# 2025-09-06 00:49:41.570238: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3c000 of size 256 next 129
# 2025-09-06 00:49:41.570243: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 74350bd3c100 of size 1280 next 135
# 2025-09-06 00:49:41.570249: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3c600 of size 256 next 89
# 2025-09-06 00:49:41.570254: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3c700 of size 256 next 82
# 2025-09-06 00:49:41.570260: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3c800 of size 256 next 88
# 2025-09-06 00:49:41.570265: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3c900 of size 256 next 101
# 2025-09-06 00:49:41.570270: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3ca00 of size 256 next 125
# 2025-09-06 00:49:41.570275: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3cb00 of size 256 next 126
# 2025-09-06 00:49:41.570281: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 74350bd3cc00 of size 4352 next 119
# 2025-09-06 00:49:41.570287: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd3dd00 of size 51712 next 144
# 2025-09-06 00:49:41.570293: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd4a700 of size 10240 next 83
# 2025-09-06 00:49:41.570299: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350bd4cf00 of size 2987520 next 67
# 2025-09-06 00:49:41.570302: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350c026500 of size 1048576 next 127
# 2025-09-06 00:49:41.570304: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350c126500 of size 1228800 next 120
# 2025-09-06 00:49:41.570307: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350c252500 of size 6277632 next 71
# 2025-09-06 00:49:41.570310: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350c84ef00 of size 14846464 next 96
# 2025-09-06 00:49:41.570313: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350d677900 of size 20480 next 44
# 2025-09-06 00:49:41.570315: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350d67c900 of size 20480 next 77
# 2025-09-06 00:49:41.570318: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350d681900 of size 20480 next 131
# 2025-09-06 00:49:41.570320: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350d686900 of size 20480 next 154
# 2025-09-06 00:49:41.570323: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350d68b900 of size 4419584 next 110
# 2025-09-06 00:49:41.570325: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dac2900 of size 29696 next 114
# 2025-09-06 00:49:41.570328: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dac9d00 of size 10240 next 158
# 2025-09-06 00:49:41.570330: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dacc500 of size 10240 next 156
# 2025-09-06 00:49:41.570333: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350daced00 of size 10240 next 84
# 2025-09-06 00:49:41.570335: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dad1500 of size 28416 next 170
# 2025-09-06 00:49:41.570337: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dad8400 of size 2901504 next 139
# 2025-09-06 00:49:41.570340: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350dd9ca00 of size 8868096 next 153
# 2025-09-06 00:49:41.570343: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350e611b00 of size 6307840 next 172
# 2025-09-06 00:49:41.570345: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350ec15b00 of size 7567360 next 157
# 2025-09-06 00:49:41.570348: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350f34d300 of size 7567360 next 136
# 2025-09-06 00:49:41.570351: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74350fa84b00 of size 15134720 next 81
# 2025-09-06 00:49:41.570354: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435108f3b00 of size 15134720 next 104
# 2025-09-06 00:49:41.570356: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743511762b00 of size 59136 next 132
# 2025-09-06 00:49:41.570359: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743511771200 of size 29696 next 95
# 2025-09-06 00:49:41.570361: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 743511778600 of size 38622976 next 117
# 2025-09-06 00:49:41.570364: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743513c4dd00 of size 25337856 next 72
# 2025-09-06 00:49:41.570367: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 743515477d00 of size 33372416 next 69
# 2025-09-06 00:49:41.570369: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 74351744b600 of size 87007744 next 116
# 2025-09-06 00:49:41.570372: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 74351c745800 of size 66744576 next 79
# 2025-09-06 00:49:41.570374: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7435206ec900 of size 365716480 next 111
# 2025-09-06 00:49:41.570377: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 7435363b2d00 of size 351589120 next 18446744073709551615
# 2025-09-06 00:49:41.570379: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1110]      Summary of in-use Chunks by size:
# 2025-09-06 00:49:41.570384: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 76 Chunks of size 256 totalling 19.0KiB
# 2025-09-06 00:49:41.570387: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1280 totalling 1.2KiB
# 2025-09-06 00:49:41.570390: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 4096 totalling 20.0KiB
# 2025-09-06 00:49:41.570393: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 6144 totalling 6.0KiB
# 2025-09-06 00:49:41.570396: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 6 Chunks of size 8192 totalling 48.0KiB
# 2025-09-06 00:49:41.570399: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 4 Chunks of size 10240 totalling 40.0KiB
# 2025-09-06 00:49:41.570402: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 12288 totalling 12.0KiB
# 2025-09-06 00:49:41.570405: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 4 Chunks of size 20480 totalling 80.0KiB
# 2025-09-06 00:49:41.570408: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 28416 totalling 27.8KiB
# 2025-09-06 00:49:41.570411: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 29696 totalling 87.0KiB
# 2025-09-06 00:49:41.570414: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 49664 totalling 145.5KiB
# 2025-09-06 00:49:41.570417: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 51712 totalling 50.5KiB
# 2025-09-06 00:49:41.570420: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 59136 totalling 115.5KiB
# 2025-09-06 00:49:41.570423: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 96000 totalling 93.8KiB
# 2025-09-06 00:49:41.570426: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 1048576 totalling 2.00MiB
# 2025-09-06 00:49:41.570429: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1146112 totalling 1.09MiB
# 2025-09-06 00:49:41.570431: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1181440 totalling 1.13MiB
# 2025-09-06 00:49:41.570434: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 1228800 totalling 3.52MiB
# 2025-09-06 00:49:41.570437: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 2097152 totalling 6.00MiB
# 2025-09-06 00:49:41.570440: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 2277376 totalling 4.34MiB
# 2025-09-06 00:49:41.570443: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 2901504 totalling 2.77MiB
# 2025-09-06 00:49:41.570446: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 2987520 totalling 2.85MiB
# 2025-09-06 00:49:41.570448: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 4194304 totalling 8.00MiB
# 2025-09-06 00:49:41.570451: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 4419584 totalling 4.21MiB
# 2025-09-06 00:49:41.570454: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 6277632 totalling 5.99MiB
# 2025-09-06 00:49:41.570457: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 6307840 totalling 6.02MiB
# 2025-09-06 00:49:41.570460: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 6598912 totalling 6.29MiB
# 2025-09-06 00:49:41.570463: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 7567360 totalling 14.43MiB
# 2025-09-06 00:49:41.570466: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 8868096 totalling 8.46MiB
# 2025-09-06 00:49:41.570469: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 14846464 totalling 28.32MiB
# 2025-09-06 00:49:41.570472: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 15134720 totalling 28.87MiB
# 2025-09-06 00:49:41.570474: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 15520000 totalling 14.80MiB
# 2025-09-06 00:49:41.570477: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 21844480 totalling 20.83MiB
# 2025-09-06 00:49:41.570480: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 25337856 totalling 72.49MiB
# 2025-09-06 00:49:41.570483: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 29875712 totalling 28.49MiB
# 2025-09-06 00:49:41.570486: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 33372416 totalling 31.83MiB
# 2025-09-06 00:49:41.570489: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 66744576 totalling 63.65MiB
# 2025-09-06 00:49:41.570492: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 365716480 totalling 348.77MiB
# 2025-09-06 00:49:41.570495: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] Sum Total of in-use chunks: 715.88MiB
# 2025-09-06 00:49:41.570498: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119] Total bytes in pool: 1227882496 memory_limit_: 1227882496 available bytes: 0 curr_region_allocation_bytes_: 2455764992
# 2025-09-06 00:49:41.570504: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1124] Stats:
# Limit:                      1227882496
# InUse:                       750655488
# MaxInUse:                   1141266432
# NumAllocs:                         920
# MaxAllocSize:                462159104
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-09-06 00:49:41.570512: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] **********************__******______************************************____________________________
# 2025-09-06 00:49:41.570535: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at sparse_xent_op.cc:98 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[7390,12372] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2025-09-06 00:49:41.570556: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[7390,12372] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{function_node __inference_one_step_on_data_6123}}{{node compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[28], line 2
#       1 model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),optimizer = "adam" , metrics = [tf.keras.metrics.SparseCategoricalCrossentropy()])
# ----> 2 model.fit(tf_ds_train,epochs=40)
#
# File ~/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/shakespere/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/asyncio/events.py", line 84, in _run
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#
#   File "/tmp/ipykernel_48600/627538764.py", line 2, in <module>
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 377, in fit
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 133, in multi_step_on_iterator
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 114, in one_step_on_data
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 61, in train_step
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 383, in _compute_loss
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 351, in compute_loss
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 690, in __call__
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 699, in call
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/losses/loss.py", line 67, in __call__
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/losses/losses.py", line 33, in call
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/losses/losses.py", line 2330, in sparse_categorical_crossentropy
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/ops/nn.py", line 2008, in sparse_categorical_crossentropy
#
#   File "/home/garvthakral/miniconda3/envs/shakespere/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py", line 753, in sparse_categorical_crossentropy
#
# OOM when allocating tensor with shape[7390,12372] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_6198]

# %%
import numpy as np
import tensorflow as tf

# Generated array init
generated_array = []

# States Init
a0 = c0 = np.zeros((1,256))
a1 = c1 = np.zeros((1,512))

# Pulling trained layers from the model
embedding_layer = model.layers[1]
lstm_layer_1 = model.layers[2]
lstm_layer_2 = model.layers[4]
dense_layer_1 = model.layers[6]

# Start tokens
inputs = tf.constant([[12]], dtype=tf.int32)  # start with first token

temperature = 0.7  # controls randomness (higher = more diverse)
top_k = 10         # optional: only consider top-k tokens

for i in range(40):
    # Embedding
    X = embedding_layer(inputs)

    # LSTM layers
    X, a0, c0 = lstm_layer_1(X, initial_state=[a0, c0])
    X, a1, c1 = lstm_layer_2(X, initial_state=[a1, c1])

    # Dense
    X = dense_layer_1(X)

    # Convert tensor to numpy
    logits = X.numpy()  # shape: (batch, seq_len, vocab_size)
    
    # Apply temperature and numerical stability
    scaled_logits = logits / temperature
    scaled_logits -= np.max(scaled_logits, axis=-1, keepdims=True)
    probs = np.exp(scaled_logits)
    probs /= probs.sum(axis=-1, keepdims=True)

    # Top-k sampling
    top_k_indices = np.argsort(probs[0, -1, :])[-top_k:]
    top_k_probs = probs[0, -1, :][top_k_indices]
    top_k_probs /= top_k_probs.sum()

    # Sample next token
    next_token = np.random.choice(top_k_indices, p=top_k_probs)

    # Append to generated array
    generated_array.append(next_token)

    # Prepare input for next step (last token only)
    inputs = tf.constant([[next_token]], dtype=tf.int32)

generated_array
# Out:
# [np.int64(131),
#  np.int64(50),
#  np.int64(84),
#  np.int64(253),
#  np.int64(1129),
#  np.int64(253),
#  np.int64(1050),
#  np.int64(55),
#  np.int64(103),
#  np.int64(249),
#  np.int64(253),
#  np.int64(350),
#  np.int64(586),
#  np.int64(196),
#  np.int64(53),
#  np.int64(297),
#  np.int64(120),
#  np.int64(257),
#  np.int64(179),
#  np.int64(120),
#  np.int64(407),
#  np.int64(9935),
#  np.int64(103),
#  np.int64(4068),
#  np.int64(50),
#  np.int64(77),
#  np.int64(200),
#  np.int64(18),
#  np.int64(251),
#  np.int64(760),
#  np.int64(75),
#  np.int64(151),
#  np.int64(583),
#  np.int64(179),
#  np.int64(18),
#  np.int64(30),
#  np.int64(27),
#  np.int64(175),
#  np.int64(75),
#  np.int64(70)]

# %%
generated_string = [index_to_word[x] for x in generated_array]
" ".join(generated_string)
# Out:
# 'them . what , ho , fie of the people , or else we have heard you know that you should arraign the tower . i think he hath been in a world that he shall not stay in his'

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
